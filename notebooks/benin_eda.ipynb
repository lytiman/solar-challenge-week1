# %%
# %pip install scipy
import pandas as pd
df = pd.read_csv("C:/Users/PC/Desktop/solar-challenge-week1/data/benin-malanville.csv", parse_dates=["Timestamp"])
display(df.describe())
display(df.isna().sum())
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#                            Timestamp            GHI            DNI  \
# count                         525600  525600.000000  525600.000000
# mean   2022-02-07 12:00:30.000000512     240.559452     167.187516
# min              2021-08-09 00:01:00     -12.900000      -7.800000
# 25%              2021-11-08 06:00:45      -2.000000      -0.500000
# 50%              2022-02-07 12:00:30       1.800000      -0.100000
# 75%              2022-05-09 18:00:15     483.400000     314.200000
# max              2022-08-09 00:00:00    1413.000000     952.300000
# std                              NaN     331.131327     261.710501
#
#                  DHI           ModA           ModB           Tamb  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# ...

# %%
from scipy import stats
for col in ["GHI","DNI","DHI","ModA","ModB","WS","WSgust"]:
    df[f"{col}_z"] = stats.zscore(df[col].dropna())

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
plt.scatter(df["Tamb"], df["GHI"], s=df["RH"]*0.5, alpha=0.6)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.to_csv("data/benin_clean.csv", index=False)
